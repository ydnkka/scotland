# %%
from utils import data

# %%
df = data.load_analysis_columns(
    ["cluster_id", "cluster_size"]
)

# %%
df.shape
# Out:
# (789347, 6)

# %%
df["sequence_id"].n_unique(), df["cluster_id"].n_unique()
# Out:
# (281320, 193160)

# %%
df["cluster_size"].describe(percentiles=[0.95])
# Out:
# shape: (7, 2)
# ┌────────────┬────────────┐
# │ statistic  ┆ value      │
# │ ---        ┆ ---        │
# │ str        ┆ f64        │
# ╞════════════╪════════════╡
# │ count      ┆ 789347.0   │
# │ null_count ┆ 0.0        │
# │ mean       ┆ 198.774422 │
# │ std        ┆ 479.787407 │
# │ min        ┆ 1.0        │
# │ 95%        ┆ 1283.0     │
# │ max        ┆ 3241.0     │
# └────────────┴────────────┘
