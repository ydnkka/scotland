# %% [markdown]
# # Candidate SSE Socio-Geodemographic Association: Clade Sensitivity
#
# Runs the full composition and node-mixing regression pipeline separately within the curated top Nextclade groups from `utils.data.CLADES`, with remaining clades grouped as `Other`. Because the data are stratified by clade group, clade is deliberately excluded from the adjustment set.

# %%
from pathlib import Path
import sys

import pandas as pd

PROJECT_ROOT = Path.cwd().resolve()
if not (PROJECT_ROOT / "config.yaml").exists():
    PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from sse_detection.lib.association_pipeline import (  # noqa: E402
    default_model_sets,
    run_association_pipeline,
)

pd.set_option("display.max_columns", 160)
pd.set_option("display.width", 220)

# %% [markdown]
# ## Model Specification

# %%
RESULT_DIR = PROJECT_ROOT / "sse_detection" / "clade_sensitivity"
MODEL_METHOD = "firth_glm"

MODEL_SETS = default_model_sets(
    variant_adjuster=None,
    window_adjustment="fixed_effects",
)

MODEL_SETS
# Out:
# {'primary': ['C(window_idx)'],
#  'expanded': ['C(window_idx)',
#   'z_dz_cum_prop_sequenced',
#   'z_dz_cum_incidence_per_capita',
#   'z_dz_7d_test_positivity',
#   'z_log1p_dz_cum_positive_tests']}

# %% [markdown]
# ## Fit and Save

# %%
result = run_association_pipeline(
    project_root=PROJECT_ROOT,
    result_dir=RESULT_DIR,
    model_method=MODEL_METHOD,
    variant_adjuster=None,
    window_adjustment="fixed_effects",
    composition_model_sets=MODEL_SETS,
    mixing_model_sets=MODEL_SETS,
    group_by_clade=True,
)

print(f"Results saved to: {result['result_dir']}")
display(result["cluster_diagnostics"])
{name: len(table) for name, table in result["summary_tables"].items()}
# Out:
# Fitted composition__primary__single__sex__20b: 1,387 rows
# Fitted composition__primary__single__age_band__20b: 1,387 rows
# Fitted composition__primary__single__simd_quintile__20b: 1,387 rows
# Fitted composition__primary__single__urban_rural_class__20b: 1,387 rows
# Fitted composition__primary__single__health_board__20b: 1,387 rows
# Fitted composition__primary__joint__20b: 1,387 rows
# Fitted composition__primary__single__sex__20a: 635 rows
# Fitted composition__primary__single__age_band__20a: 635 rows
# Fitted composition__primary__single__simd_quintile__20a: 635 rows
# Fitted composition__primary__single__urban_rural_class__20a: 635 rows
# Fitted composition__primary__single__health_board__20a: 635 rows
# Fitted composition__primary__joint__20a: 635 rows
# Fitted composition__primary__single__sex__20e_eu1: 6,347 rows
# Fitted composition__primary__single__age_band__20e_eu1: 6,347 rows
# Fitted composition__primary__single__simd_quintile__20e_eu1: 6,347 rows
# Fitted composition__primary__single__urban_rural_class__20e_eu1: 6,347 rows
# Fitted composition__primary__single__health_board__20e_eu1: 6,347 rows
# Fitted composition__primary__joint__20e_eu1: 6,347 rows
# Fitted composition__primary__single__sex__20i_alpha: 32,008 rows
# Fitted composition__primary__single__age_band__20i_alpha: 32,008 rows
# Fitted composition__primary__single__simd_quintile__20i_alpha: 32,008 rows
# Fitted composition__primary__single__urban_rural_class__20i_alpha: 32,008 rows
# Fitted composition__primary__single__health_board__20i_alpha: 32,008 rows
# Fitted composition__primary__joint__20i_alpha: 32,008 rows
# Fitted composition__primary__single__sex__21k_omicron: 55,604 rows
# Fitted composition__primary__single__age_band__21k_omicron: 55,604 rows
# Fitted composition__primary__single__simd_quintile__21k_omicron: 55,604 rows
# Fitted composition__primary__single__urban_rural_class__21k_omicron: 55,604 rows
# Fitted composition__primary__single__health_board__21k_omicron: 55,604 rows
# Fitted composition__primary__joint__21k_omicron: 55,604 rows
# Fitted composition__primary__single__sex__21j_delta: 97,173 rows
# Fitted composition__primary__single__age_band__21j_delta: 97,173 rows
# Fitted composition__primary__single__simd_quintile__21j_delta: 97,173 rows
# Fitted composition__primary__single__urban_rural_class__21j_delta: 97,173 rows
# Fitted composition__primary__single__health_board__21j_delta: 97,173 rows
# Fitted composition__primary__joint__21j_delta: 97,173 rows
# Fitted composition__primary__single__sex__21i_delta: 564 rows
# Fitted composition__primary__single__age_band__21i_delta: 564 rows
# Fitted composition__primary__single__simd_quintile__21i_delta: 564 rows
# Fitted composition__primary__single__urban_rural_class__21i_delta: 564 rows
# Fitted composition__primary__single__health_board__21i_delta: 564 rows
# Fitted composition__primary__joint__21i_delta: 564 rows
# Fitted composition__primary__single__sex__21l_omicron: 55,166 rows
# Fitted composition__primary__single__age_band__21l_omicron: 55,166 rows
# Fitted composition__primary__single__simd_quintile__21l_omicron: 55,166 rows
# Fitted composition__primary__single__urban_rural_class__21l_omicron: 55,166 rows
# Fitted composition__primary__single__health_board__21l_omicron: 55,166 rows
# Fitted composition__primary__joint__21l_omicron: 55,166 rows
# Fitted composition__primary__single__sex__22b_omicron: 9,686 rows
# Fitted composition__primary__single__age_band__22b_omicron: 9,686 rows
# Fitted composition__primary__single__simd_quintile__22b_omicron: 9,686 rows
# Fitted composition__primary__single__urban_rural_class__22b_omicron: 9,686 rows
# Fitted composition__primary__single__health_board__22b_omicron: 9,686 rows
# Fitted composition__primary__joint__22b_omicron: 9,686 rows
# Fitted composition__primary__single__sex__22a_omicron: 1,500 rows
# Fitted composition__primary__single__age_band__22a_omicron: 1,500 rows
# Fitted composition__primary__single__simd_quintile__22a_omicron: 1,500 rows
# Fitted composition__primary__single__urban_rural_class__22a_omicron: 1,500 rows
# Fitted composition__primary__single__health_board__22a_omicron: 1,500 rows
# Fitted composition__primary__joint__22a_omicron: 1,500 rows
# Fitted composition__primary__single__sex__22c_omicron: 706 rows
# Fitted composition__primary__single__age_band__22c_omicron: 706 rows
# Fitted composition__primary__single__simd_quintile__22c_omicron: 706 rows
# Fitted composition__primary__single__urban_rural_class__22c_omicron: 706 rows
# Fitted composition__primary__single__health_board__22c_omicron: 706 rows
# Fitted composition__primary__joint__22c_omicron: 706 rows
# Fitted composition__primary__single__sex__22e_omicron: 955 rows
# Fitted composition__primary__single__age_band__22e_omicron: 955 rows
# Fitted composition__primary__single__simd_quintile__22e_omicron: 955 rows
# Fitted composition__primary__single__urban_rural_class__22e_omicron: 955 rows
# Fitted composition__primary__single__health_board__22e_omicron: 955 rows
# Fitted composition__primary__joint__22e_omicron: 955 rows
# Fitted composition__primary__single__sex__other: 1,201 rows
# Fitted composition__primary__single__age_band__other: 1,201 rows
# Fitted composition__primary__single__simd_quintile__other: 1,201 rows
# Fitted composition__primary__single__urban_rural_class__other: 1,201 rows
# Fitted composition__primary__single__health_board__other: 1,201 rows
# Fitted composition__primary__joint__other: 1,201 rows
# Fitted composition__expanded__single__sex__20b: 1,378 rows
# Fitted composition__expanded__single__age_band__20b: 1,378 rows
# Fitted composition__expanded__single__simd_quintile__20b: 1,378 rows
# Fitted composition__expanded__single__urban_rural_class__20b: 1,378 rows
# Fitted composition__expanded__single__health_board__20b: 1,378 rows
# Fitted composition__expanded__joint__20b: 1,378 rows
# Fitted composition__expanded__single__sex__20a: 634 rows
# Fitted composition__expanded__single__age_band__20a: 634 rows
# Fitted composition__expanded__single__simd_quintile__20a: 634 rows
# Fitted composition__expanded__single__urban_rural_class__20a: 634 rows
# Fitted composition__expanded__single__health_board__20a: 634 rows
# Fitted composition__expanded__joint__20a: 634 rows
# Fitted composition__expanded__single__sex__20e_eu1: 6,343 rows
# Fitted composition__expanded__single__age_band__20e_eu1: 6,343 rows
# Fitted composition__expanded__single__simd_quintile__20e_eu1: 6,343 rows
# Fitted composition__expanded__single__urban_rural_class__20e_eu1: 6,343 rows
# Fitted composition__expanded__single__health_board__20e_eu1: 6,343 rows
# Fitted composition__expanded__joint__20e_eu1: 6,343 rows
# Fitted composition__expanded__single__sex__20i_alpha: 32,008 rows
# Fitted composition__expanded__single__age_band__20i_alpha: 32,008 rows
# Fitted composition__expanded__single__simd_quintile__20i_alpha: 32,008 rows
# Fitted composition__expanded__single__urban_rural_class__20i_alpha: 32,008 rows
# Fitted composition__expanded__single__health_board__20i_alpha: 32,008 rows
# Fitted composition__expanded__joint__20i_alpha: 32,008 rows
# Fitted composition__expanded__single__sex__21k_omicron: 55,604 rows
# Fitted composition__expanded__single__age_band__21k_omicron: 55,604 rows
# Fitted composition__expanded__single__simd_quintile__21k_omicron: 55,604 rows
# Fitted composition__expanded__single__urban_rural_class__21k_omicron: 55,604 rows
# Fitted composition__expanded__single__health_board__21k_omicron: 55,604 rows
# Fitted composition__expanded__joint__21k_omicron: 55,604 rows
# Fitted composition__expanded__single__sex__21j_delta: 97,173 rows
# Fitted composition__expanded__single__age_band__21j_delta: 97,173 rows
# Fitted composition__expanded__single__simd_quintile__21j_delta: 97,173 rows
# Fitted composition__expanded__single__urban_rural_class__21j_delta: 97,173 rows
# Fitted composition__expanded__single__health_board__21j_delta: 97,173 rows
# Fitted composition__expanded__joint__21j_delta: 97,173 rows
# Fitted composition__expanded__single__sex__21i_delta: 564 rows
# Fitted composition__expanded__single__age_band__21i_delta: 564 rows
# Fitted composition__expanded__single__simd_quintile__21i_delta: 564 rows
# Fitted composition__expanded__single__urban_rural_class__21i_delta: 564 rows
# Fitted composition__expanded__single__health_board__21i_delta: 564 rows
# Fitted composition__expanded__joint__21i_delta: 564 rows
# Fitted composition__expanded__single__sex__21l_omicron: 55,166 rows
# Fitted composition__expanded__single__age_band__21l_omicron: 55,166 rows
# Fitted composition__expanded__single__simd_quintile__21l_omicron: 55,166 rows
# Fitted composition__expanded__single__urban_rural_class__21l_omicron: 55,166 rows
# Fitted composition__expanded__single__health_board__21l_omicron: 55,166 rows
# Fitted composition__expanded__joint__21l_omicron: 55,166 rows
# Fitted composition__expanded__single__sex__22b_omicron: 9,682 rows
# Fitted composition__expanded__single__age_band__22b_omicron: 9,682 rows
# Fitted composition__expanded__single__simd_quintile__22b_omicron: 9,682 rows
# Fitted composition__expanded__single__urban_rural_class__22b_omicron: 9,682 rows
# Fitted composition__expanded__single__health_board__22b_omicron: 9,682 rows
# Fitted composition__expanded__joint__22b_omicron: 9,682 rows
# Fitted composition__expanded__single__sex__22a_omicron: 1,500 rows
# Fitted composition__expanded__single__age_band__22a_omicron: 1,500 rows
# Fitted composition__expanded__single__simd_quintile__22a_omicron: 1,500 rows
# Fitted composition__expanded__single__urban_rural_class__22a_omicron: 1,500 rows
# Fitted composition__expanded__single__health_board__22a_omicron: 1,500 rows
# Fitted composition__expanded__joint__22a_omicron: 1,500 rows
# Fitted composition__expanded__single__sex__22c_omicron: 706 rows
# Fitted composition__expanded__single__age_band__22c_omicron: 706 rows
# Fitted composition__expanded__single__simd_quintile__22c_omicron: 706 rows
# Fitted composition__expanded__single__urban_rural_class__22c_omicron: 706 rows
# Fitted composition__expanded__single__health_board__22c_omicron: 706 rows
# Fitted composition__expanded__joint__22c_omicron: 706 rows
# Fitted composition__expanded__single__sex__22e_omicron: 953 rows
# Fitted composition__expanded__single__age_band__22e_omicron: 953 rows
# Fitted composition__expanded__single__simd_quintile__22e_omicron: 953 rows
# Fitted composition__expanded__single__urban_rural_class__22e_omicron: 953 rows
# Fitted composition__expanded__single__health_board__22e_omicron: 953 rows
# Fitted composition__expanded__joint__22e_omicron: 953 rows
# Fitted composition__expanded__single__sex__other: 1,201 rows
# Fitted composition__expanded__single__age_band__other: 1,201 rows
# Fitted composition__expanded__single__simd_quintile__other: 1,201 rows
# Fitted composition__expanded__single__urban_rural_class__other: 1,201 rows
# Fitted composition__expanded__single__health_board__other: 1,201 rows
# Fitted composition__expanded__joint__other: 1,201 rows
# Fitted mixing__primary__single__sex_entropy_z__20b: 58 nodes
# Fitted mixing__primary__single__age_entropy_z__20b: 58 nodes
# Fitted mixing__primary__single__simd_entropy_z__20b: 58 nodes
# Fitted mixing__primary__single__urban_rural_entropy_z__20b: 58 nodes
# Fitted mixing__primary__single__health_board_entropy_z__20b: 58 nodes
# Fitted mixing__primary__joint__20b: 58 nodes
# Fitted mixing__primary__single__sex_entropy_z__20a: 30 nodes
# Fitted mixing__primary__single__age_entropy_z__20a: 30 nodes
# Fitted mixing__primary__single__simd_entropy_z__20a: 30 nodes
# Fitted mixing__primary__single__urban_rural_entropy_z__20a: 30 nodes
# Fitted mixing__primary__single__health_board_entropy_z__20a: 30 nodes
# Fitted mixing__primary__joint__20a: 30 nodes
# Fitted mixing__primary__single__sex_entropy_z__20e_eu1: 342 nodes
# Fitted mixing__primary__single__age_entropy_z__20e_eu1: 342 nodes
# Fitted mixing__primary__single__simd_entropy_z__20e_eu1: 342 nodes
# Fitted mixing__primary__single__urban_rural_entropy_z__20e_eu1: 342 nodes
# Fitted mixing__primary__single__health_board_entropy_z__20e_eu1: 342 nodes
# Fitted mixing__primary__joint__20e_eu1: 342 nodes
# Fitted mixing__primary__single__sex_entropy_z__20i_alpha: 1,504 nodes
# Fitted mixing__primary__single__age_entropy_z__20i_alpha: 1,504 nodes
# Fitted mixing__primary__single__simd_entropy_z__20i_alpha: 1,504 nodes
# Fitted mixing__primary__single__urban_rural_entropy_z__20i_alpha: 1,504 nodes
# Fitted mixing__primary__single__health_board_entropy_z__20i_alpha: 1,504 nodes
# Fitted mixing__primary__joint__20i_alpha: 1,504 nodes
# Fitted mixing__primary__single__sex_entropy_z__21k_omicron: 1,730 nodes
# Fitted mixing__primary__single__age_entropy_z__21k_omicron: 1,730 nodes
# Fitted mixing__primary__single__simd_entropy_z__21k_omicron: 1,730 nodes
# Fitted mixing__primary__single__urban_rural_entropy_z__21k_omicron: 1,730 nodes
# Fitted mixing__primary__single__health_board_entropy_z__21k_omicron: 1,730 nodes
# Fitted mixing__primary__joint__21k_omicron: 1,730 nodes
# Fitted mixing__primary__single__sex_entropy_z__21j_delta: 5,336 nodes
# Fitted mixing__primary__single__age_entropy_z__21j_delta: 5,336 nodes
# Fitted mixing__primary__single__simd_entropy_z__21j_delta: 5,336 nodes
# Fitted mixing__primary__single__urban_rural_entropy_z__21j_delta: 5,336 nodes
# Fitted mixing__primary__single__health_board_entropy_z__21j_delta: 5,336 nodes
# Fitted mixing__primary__joint__21j_delta: 5,336 nodes
# Fitted mixing__primary__single__sex_entropy_z__21i_delta: 37 nodes
# Fitted mixing__primary__single__age_entropy_z__21i_delta: 37 nodes
# Fitted mixing__primary__single__simd_entropy_z__21i_delta: 37 nodes
# Fitted mixing__primary__single__urban_rural_entropy_z__21i_delta: 37 nodes
# Fitted mixing__primary__single__health_board_entropy_z__21i_delta: 37 nodes
# Fitted mixing__primary__joint__21i_delta: 37 nodes
# Fitted mixing__primary__single__sex_entropy_z__21l_omicron: 2,502 nodes
# Fitted mixing__primary__single__age_entropy_z__21l_omicron: 2,502 nodes
# Fitted mixing__primary__single__simd_entropy_z__21l_omicron: 2,502 nodes
# Fitted mixing__primary__single__urban_rural_entropy_z__21l_omicron: 2,502 nodes
# Fitted mixing__primary__single__health_board_entropy_z__21l_omicron: 2,502 nodes
# Fitted mixing__primary__joint__21l_omicron: 2,502 nodes
# Fitted mixing__primary__single__sex_entropy_z__22b_omicron: 913 nodes
# Fitted mixing__primary__single__age_entropy_z__22b_omicron: 913 nodes
# Fitted mixing__primary__single__simd_entropy_z__22b_omicron: 913 nodes
# Fitted mixing__primary__single__urban_rural_entropy_z__22b_omicron: 913 nodes
# Fitted mixing__primary__single__health_board_entropy_z__22b_omicron: 913 nodes
# Fitted mixing__primary__joint__22b_omicron: 913 nodes
# Fitted mixing__primary__single__sex_entropy_z__22a_omicron: 109 nodes
# Fitted mixing__primary__single__age_entropy_z__22a_omicron: 109 nodes
# Fitted mixing__primary__single__simd_entropy_z__22a_omicron: 109 nodes
# Fitted mixing__primary__single__urban_rural_entropy_z__22a_omicron: 109 nodes
# Fitted mixing__primary__single__health_board_entropy_z__22a_omicron: 109 nodes
# Fitted mixing__primary__joint__22a_omicron: 109 nodes
# Fitted mixing__primary__single__sex_entropy_z__22c_omicron: 51 nodes
# Fitted mixing__primary__single__age_entropy_z__22c_omicron: 51 nodes
# Fitted mixing__primary__single__simd_entropy_z__22c_omicron: 51 nodes
# Fitted mixing__primary__single__urban_rural_entropy_z__22c_omicron: 51 nodes
# Fitted mixing__primary__single__health_board_entropy_z__22c_omicron: 51 nodes
# Fitted mixing__primary__joint__22c_omicron: 51 nodes
# Fitted mixing__primary__single__sex_entropy_z__22e_omicron: 171 nodes
# Fitted mixing__primary__single__age_entropy_z__22e_omicron: 171 nodes
# Fitted mixing__primary__single__simd_entropy_z__22e_omicron: 171 nodes
# Fitted mixing__primary__single__urban_rural_entropy_z__22e_omicron: 171 nodes
# Fitted mixing__primary__single__health_board_entropy_z__22e_omicron: 171 nodes
# Fitted mixing__primary__joint__22e_omicron: 171 nodes
# Fitted mixing__primary__single__sex_entropy_z__other: 110 nodes
# Fitted mixing__primary__single__age_entropy_z__other: 110 nodes
# Fitted mixing__primary__single__simd_entropy_z__other: 110 nodes
# Fitted mixing__primary__single__urban_rural_entropy_z__other: 110 nodes
# Fitted mixing__primary__single__health_board_entropy_z__other: 110 nodes
# Fitted mixing__primary__joint__other: 110 nodes
# Fitted mixing__expanded__single__sex_entropy_z__20b: 58 nodes
# Fitted mixing__expanded__single__age_entropy_z__20b: 58 nodes
# Fitted mixing__expanded__single__simd_entropy_z__20b: 58 nodes
# Fitted mixing__expanded__single__urban_rural_entropy_z__20b: 58 nodes
# Fitted mixing__expanded__single__health_board_entropy_z__20b: 58 nodes
# Fitted mixing__expanded__joint__20b: 58 nodes
# Fitted mixing__expanded__single__sex_entropy_z__20a: 30 nodes
# Fitted mixing__expanded__single__age_entropy_z__20a: 30 nodes
# Fitted mixing__expanded__single__simd_entropy_z__20a: 30 nodes
# Fitted mixing__expanded__single__urban_rural_entropy_z__20a: 30 nodes
# Fitted mixing__expanded__single__health_board_entropy_z__20a: 30 nodes
# Fitted mixing__expanded__joint__20a: 30 nodes
# Fitted mixing__expanded__single__sex_entropy_z__20e_eu1: 342 nodes
# Fitted mixing__expanded__single__age_entropy_z__20e_eu1: 342 nodes
# Fitted mixing__expanded__single__simd_entropy_z__20e_eu1: 342 nodes
# Fitted mixing__expanded__single__urban_rural_entropy_z__20e_eu1: 342 nodes
# Fitted mixing__expanded__single__health_board_entropy_z__20e_eu1: 342 nodes
# Fitted mixing__expanded__joint__20e_eu1: 342 nodes
# Fitted mixing__expanded__single__sex_entropy_z__20i_alpha: 1,504 nodes
# Fitted mixing__expanded__single__age_entropy_z__20i_alpha: 1,504 nodes
# Fitted mixing__expanded__single__simd_entropy_z__20i_alpha: 1,504 nodes
# Fitted mixing__expanded__single__urban_rural_entropy_z__20i_alpha: 1,504 nodes
# Fitted mixing__expanded__single__health_board_entropy_z__20i_alpha: 1,504 nodes
# Fitted mixing__expanded__joint__20i_alpha: 1,504 nodes
# Fitted mixing__expanded__single__sex_entropy_z__21k_omicron: 1,730 nodes
# Fitted mixing__expanded__single__age_entropy_z__21k_omicron: 1,730 nodes
# Fitted mixing__expanded__single__simd_entropy_z__21k_omicron: 1,730 nodes
# Fitted mixing__expanded__single__urban_rural_entropy_z__21k_omicron: 1,730 nodes
# Fitted mixing__expanded__single__health_board_entropy_z__21k_omicron: 1,730 nodes
# Fitted mixing__expanded__joint__21k_omicron: 1,730 nodes
# Fitted mixing__expanded__single__sex_entropy_z__21j_delta: 5,336 nodes
# Fitted mixing__expanded__single__age_entropy_z__21j_delta: 5,336 nodes
# Fitted mixing__expanded__single__simd_entropy_z__21j_delta: 5,336 nodes
# Fitted mixing__expanded__single__urban_rural_entropy_z__21j_delta: 5,336 nodes
# Fitted mixing__expanded__single__health_board_entropy_z__21j_delta: 5,336 nodes
# Fitted mixing__expanded__joint__21j_delta: 5,336 nodes
# Fitted mixing__expanded__single__sex_entropy_z__21i_delta: 37 nodes
# Fitted mixing__expanded__single__age_entropy_z__21i_delta: 37 nodes
# Fitted mixing__expanded__single__simd_entropy_z__21i_delta: 37 nodes
# Fitted mixing__expanded__single__urban_rural_entropy_z__21i_delta: 37 nodes
# Fitted mixing__expanded__single__health_board_entropy_z__21i_delta: 37 nodes
# Fitted mixing__expanded__joint__21i_delta: 37 nodes
# Fitted mixing__expanded__single__sex_entropy_z__21l_omicron: 2,502 nodes
# Fitted mixing__expanded__single__age_entropy_z__21l_omicron: 2,502 nodes
# Fitted mixing__expanded__single__simd_entropy_z__21l_omicron: 2,502 nodes
# Fitted mixing__expanded__single__urban_rural_entropy_z__21l_omicron: 2,502 nodes
# Fitted mixing__expanded__single__health_board_entropy_z__21l_omicron: 2,502 nodes
# Fitted mixing__expanded__joint__21l_omicron: 2,502 nodes
# Fitted mixing__expanded__single__sex_entropy_z__22b_omicron: 913 nodes
# Fitted mixing__expanded__single__age_entropy_z__22b_omicron: 913 nodes
# Fitted mixing__expanded__single__simd_entropy_z__22b_omicron: 913 nodes
# Fitted mixing__expanded__single__urban_rural_entropy_z__22b_omicron: 913 nodes
# Fitted mixing__expanded__single__health_board_entropy_z__22b_omicron: 913 nodes
# Fitted mixing__expanded__joint__22b_omicron: 913 nodes
# Fitted mixing__expanded__single__sex_entropy_z__22a_omicron: 109 nodes
# Fitted mixing__expanded__single__age_entropy_z__22a_omicron: 109 nodes
# Fitted mixing__expanded__single__simd_entropy_z__22a_omicron: 109 nodes
# Fitted mixing__expanded__single__urban_rural_entropy_z__22a_omicron: 109 nodes
# Fitted mixing__expanded__single__health_board_entropy_z__22a_omicron: 109 nodes
# Fitted mixing__expanded__joint__22a_omicron: 109 nodes
# Fitted mixing__expanded__single__sex_entropy_z__22c_omicron: 51 nodes
# Fitted mixing__expanded__single__age_entropy_z__22c_omicron: 51 nodes
# Fitted mixing__expanded__single__simd_entropy_z__22c_omicron: 51 nodes
# Fitted mixing__expanded__single__urban_rural_entropy_z__22c_omicron: 51 nodes
# Fitted mixing__expanded__single__health_board_entropy_z__22c_omicron: 51 nodes
# Fitted mixing__expanded__joint__22c_omicron: 51 nodes
# Fitted mixing__expanded__single__sex_entropy_z__22e_omicron: 171 nodes
# Fitted mixing__expanded__single__age_entropy_z__22e_omicron: 171 nodes
# Fitted mixing__expanded__single__simd_entropy_z__22e_omicron: 171 nodes
# Fitted mixing__expanded__single__urban_rural_entropy_z__22e_omicron: 171 nodes
# Fitted mixing__expanded__single__health_board_entropy_z__22e_omicron: 171 nodes
# Fitted mixing__expanded__joint__22e_omicron: 171 nodes
# Fitted mixing__expanded__single__sex_entropy_z__other: 110 nodes
# Fitted mixing__expanded__single__age_entropy_z__other: 110 nodes
# Fitted mixing__expanded__single__simd_entropy_z__other: 110 nodes
# Fitted mixing__expanded__single__urban_rural_entropy_z__other: 110 nodes
# Fitted mixing__expanded__single__health_board_entropy_z__other: 110 nodes
# Fitted mixing__expanded__joint__other: 110 nodes
# saved composition_wald.csv: 260 rows
# saved composition_odds_ratios.csv: 1,924 rows
# saved composition_fit_stats.csv: 156 rows
# saved mixing_wald.csv: 260 rows
# saved mixing_odds_ratios.csv: 260 rows
# saved mixing_fit_stats.csv: 156 rows
# Results saved to: /Users/ydnkka/Desktop/PhD Project/projects/scotland/sse_detection/clade_sensitivity
#   cluster_col  n_rows  n_clusters  min_rows_per_cluster  median_rows_per_cluster  outcome_positive_clusters  outcome_varying_clusters analysis_frame
# 0  cluster_id  264139       13059                     1                      9.0                       6907                         0    composition
# 1  cluster_id   13059       13059                     1                      1.0                       6907                         0    node_mixing
# {'composition_wald.csv': 260,
#  'composition_odds_ratios.csv': 1924,
#  'composition_fit_stats.csv': 156,
#  'mixing_wald.csv': 260,
#  'mixing_odds_ratios.csv': 260,
#  'mixing_fit_stats.csv': 156}

# %%
if not result["failures"].empty:
    display(result["failures"])
else:
    print("No model failures recorded.")
# Out:
# No model failures recorded.
